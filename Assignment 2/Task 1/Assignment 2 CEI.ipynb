# %% [markdown]
# ## Step 1: Load dataset into a SQL database.

# %%
# Creating a database in mySQL server
MariaDB [(none)]> create database superstore_db;

Query OK, 1 row affected (0.333 sec)

# %%
MariaDB [(none)]> use superstore_db

Database changed

# %% [markdown]
# ## Step 2: Explore table (schema, sample data)

# %%
# Creating table and inserting data from csv into it
MariaDB [superstore_db]> create table superstore_data (row_id int primary key, order_id varchar(30) not null, order_date date not null, ship_date date, ship_mode varchar(30), customer_id varchar(30), customer_name varchar(30), segment varchar(30), country varchar(50), city varchar(50), state varchar(50), postal_code int, region varchar(30), product_id varchar(30), category varchar(30), sub_category varchar(30), product_name varchar(500));
Query OK, 0 rows affected (2.486 sec)

MariaDB [superstore_db]> desc superstore_data;
+---------------+--------------+------+-----+---------+-------+
| Field         | Type         | Null | Key | Default | Extra |
+---------------+--------------+------+-----+---------+-------+
| row_id        | int(11)      | NO   | PRI | NULL    |       |
| order_id      | varchar(30)  | NO   |     | NULL    |       |
| order_date    | date         | NO   |     | NULL    |       |
| ship_date     | date         | YES  |     | NULL    |       |
| ship_mode     | varchar(30)  | YES  |     | NULL    |       |
| customer_id   | varchar(30)  | YES  |     | NULL    |       |
| customer_name | varchar(30)  | YES  |     | NULL    |       |
| segment       | varchar(30)  | YES  |     | NULL    |       |
| country       | varchar(50)  | YES  |     | NULL    |       |
| city          | varchar(50)  | YES  |     | NULL    |       |
| state         | varchar(50)  | YES  |     | NULL    |       |
| postal_code   | int(11)      | YES  |     | NULL    |       |
| region        | varchar(30)  | YES  |     | NULL    |       |
| product_id    | varchar(30)  | YES  |     | NULL    |       |
| category      | varchar(30)  | YES  |     | NULL    |       |
| sub_category  | varchar(30)  | YES  |     | NULL    |       |
| product_name  | varchar(500) | YES  |     | NULL    |       |
+---------------+--------------+------+-----+---------+-------+

# %%
MariaDB [superstore_db]> load data infile "Sample - Superstore.csv" into table superstore_data fields terminated by ',' enclosed by '"' lines terminated by '\n' ignore 1 lines;
Query OK, 9994 rows affected, 10361 warnings (1.603 sec)
Records: 9994  Deleted: 0  Skipped: 0  Warnings: 10361

# %%
MariaDB [superstore_db]> select * from superstore_data limit 5;
+--------+----------------+------------+------------+----------------+-------------+-----------------+-----------+---------------+-----------------+------------+-------------+--------+-----------------+-----------------+--------------+-------------------------------------------------------------+
| row_id | order_id       | order_date | ship_date  | ship_mode      | customer_id | customer_name   | segment   | country       | city            | state      | postal_code | region | product_id      | category        | sub_category | product_name                                                |
+--------+----------------+------------+------------+----------------+-------------+-----------------+-----------+---------------+-----------------+------------+-------------+--------+-----------------+-----------------+--------------+-------------------------------------------------------------+
|      1 | CA-2016-152156 | 11/8/2016  | 11/11/2016 | Second Class   | CG-12520    | Claire Gute     | Consumer  | United States | Henderson       | Kentucky   |       42420 | South  | FUR-BO-10001798 | Furniture       | Bookcases    | Bush Somerset Collection Bookcase                           |
|      2 | CA-2016-152156 | 11/8/2016  | 11/11/2016 | Second Class   | CG-12520    | Claire Gute     | Consumer  | United States | Henderson       | Kentucky   |       42420 | South  | FUR-CH-10000454 | Furniture       | Chairs       | Hon Deluxe Fabric Upholstered Stacking Chairs, Rounded Back |
|      3 | CA-2016-138688 | 6/12/2016  | 6/16/2016  | Second Class   | DV-13045    | Darrin Van Huff | Corporate | United States | Los Angeles     | California |       90036 | West   | OFF-LA-10000240 | Office Supplies | Labels       | Self-Adhesive Address Labels for Typewriters by Universal   |
|      4 | US-2015-108966 | 10/11/2015 | 10/18/2015 | Standard Class | SO-20335    | Sean O'Donnell  | Consumer  | United States | Fort Lauderdale | Florida    |       33311 | South  | FUR-TA-10000577 | Furniture       | Tables       | Bretford CR4500 Series Slim Rectangular Table               |
|      5 | US-2015-108966 | 10/11/2015 | 10/18/2015 | Standard Class | SO-20335    | Sean O'Donnell  | Consumer  | United States | Fort Lauderdale | Florida    |       33311 | South  | OFF-ST-10000760 | Office Supplies | Storage      | Eldon Fold 'N Roll Cart System                              |
+--------+----------------+------------+------------+----------------+-------------+-----------------+-----------+---------------+-----------------+------------+-------------+--------+-----------------+-----------------+--------------+-------------------------------------------------------------+
5 rows in set (0.002 sec)

# %% [markdown]
# ## Step 3: Apply WHERE filters

# %%
# Using where filter to see data related to specfic region
MariaDB [superstore_db]> select * from superstore_data where region = 'Central' limit 5;
+--------+----------------+------------+------------+----------------+-------------+---------------+-------------+---------------+------------+-----------+-------------+---------+-----------------+-----------------+--------------+------------------------------------------------------------------------------+
| row_id | order_id       | order_date | ship_date  | ship_mode      | customer_id | customer_name | segment     | country       | city       | state     | postal_code | region  | product_id      | category        | sub_category | product_name                                                                 |
+--------+----------------+------------+------------+----------------+-------------+---------------+-------------+---------------+------------+-----------+-------------+---------+-----------------+-----------------+--------------+------------------------------------------------------------------------------+
|     15 | US-2015-118983 | 11/22/2015 | 11/26/2015 | Standard Class | HP-14815    | Harold Pawlan | Home Office | United States | Fort Worth | Texas     |       76106 | Central | OFF-AP-10002311 | Office Supplies | Appliances   | Holmes Replacement Filter for HEPA Air Cleaner, Very Large Room, HEPA Filter |
|     16 | US-2015-118983 | 11/22/2015 | 11/26/2015 | Standard Class | HP-14815    | Harold Pawlan | Home Office | United States | Fort Worth | Texas     |       76106 | Central | OFF-BI-10000756 | Office Supplies | Binders      | Storex DuraTech Recycled Plastic Frosted Binders                             |
|     17 | CA-2014-105893 | 11/11/2014 | 11/18/2014 | Standard Class | PK-19075    | Pete Kriz     | Consumer    | United States | Madison    | Wisconsin |       53711 | Central | OFF-ST-10004186 | Office Supplies | Storage      | Stur-D-Stor Shelving, Vertical 5-Shelf: 72"H x 36"W x 18 1/2"D               |
|     22 | CA-2016-137330 | 12/9/2016  | 12/13/2016 | Standard Class | KB-16585    | Ken Black     | Corporate   | United States | Fremont    | Nebraska  |       68025 | Central | OFF-AR-10000246 | Office Supplies | Art          | Newell 318                                                                   |
|     23 | CA-2016-137330 | 12/9/2016  | 12/13/2016 | Standard Class | KB-16585    | Ken Black     | Corporate   | United States | Fremont    | Nebraska  |       68025 | Central | OFF-AP-10001492 | Office Supplies | Appliances   | Acco Six-Outlet Power Strip, 4' Cord Length                                  |
+--------+----------------+------------+------------+----------------+-------------+---------------+-------------+---------------+------------+-----------+-------------+---------+-----------------+-----------------+--------------+------------------------------------------------------------------------------+
5 rows in set (0.001 sec)

# %%
# Using where filter to see data related to specfic category
MariaDB [superstore_db]> select * from superstore_data where category = 'Technology' limit 5;
+--------+----------------+------------+------------+----------------+-------------+--------------------+-----------+---------------+---------------+------------+-------------+---------+-----------------+------------+--------------+--------------------------------------------------+
| row_id | order_id       | order_date | ship_date  | ship_mode      | customer_id | customer_name      | segment   | country       | city          | state      | postal_code | region  | product_id      | category   | sub_category | product_name                                     |
+--------+----------------+------------+------------+----------------+-------------+--------------------+-----------+---------------+---------------+------------+-------------+---------+-----------------+------------+--------------+--------------------------------------------------+
|      8 | CA-2014-115812 | 6/9/2014   | 6/14/2014  | Standard Class | BH-11710    | Brosina Hoffman    | Consumer  | United States | Los Angeles   | California |       90032 | West    | TEC-PH-10002275 | Technology | Phones       | Mitel 5320 IP Phone VoIP phone                   |
|     12 | CA-2014-115812 | 6/9/2014   | 6/14/2014  | Standard Class | BH-11710    | Brosina Hoffman    | Consumer  | United States | Los Angeles   | California |       90032 | West    | TEC-PH-10002033 | Technology | Phones       | Konftel 250 Conference?phone?- Charcoal black    |
|     20 | CA-2014-143336 | 8/27/2014  | 9/1/2014   | Second Class   | ZD-21925    | Zuschuss Donatelli | Consumer  | United States | San Francisco | California |       94109 | West    | TEC-PH-10001949 | Technology | Phones       | Cisco SPA 501G IP Phone                          |
|     27 | CA-2016-121755 | 1/16/2016  | 1/20/2016  | Second Class   | EH-13945    | Eric Hoffmann      | Consumer  | United States | Los Angeles   | California |       90049 | West    | TEC-AC-10003027 | Technology | Accessories  | Imation?8GB Mini TravelDrive USB 2.0?Flash Drive |
|     36 | CA-2016-117590 | 12/8/2016  | 12/10/2016 | First Class    | GH-14485    | Gene Hale          | Corporate | United States | Richardson    | Texas      |       75080 | Central | TEC-PH-10004977 | Technology | Phones       | GE 30524EE4                                      |
+--------+----------------+------------+------------+----------------+-------------+--------------------+-----------+---------------+---------------+------------+-------------+---------+-----------------+------------+--------------+--------------------------------------------------+
5 rows in set (0.002 sec)

# %%
# Using where filter to see data related to specfic order dates
MariaDB [superstore_db]> select * from superstore_data where order_date <= '10-11-2015' limit 5;
+--------+----------------+------------+-----------+--------------+-------------+---------------+----------+---------------+-------------+------------+-------------+---------+-----------------+-----------------+--------------+--------------------------------------------------+
| row_id | order_id       | order_date | ship_date | ship_mode    | customer_id | customer_name | segment  | country       | city        | state      | postal_code | region  | product_id      | category        | sub_category | product_name                                     |
+--------+----------------+------------+-----------+--------------+-------------+---------------+----------+---------------+-------------+------------+-------------+---------+-----------------+-----------------+--------------+--------------------------------------------------+
|     26 | CA-2016-121755 | 1/16/2016  | 1/20/2016 | Second Class | EH-13945    | Eric Hoffmann | Consumer | United States | Los Angeles | California |       90049 | West    | OFF-BI-10001634 | Office Supplies | Binders      | Wilson Jones Active Use Binders                  |
|     27 | CA-2016-121755 | 1/16/2016  | 1/20/2016 | Second Class | EH-13945    | Eric Hoffmann | Consumer | United States | Los Angeles | California |       90049 | West    | TEC-AC-10003027 | Technology      | Accessories  | Imation?8GB Mini TravelDrive USB 2.0?Flash Drive |
|     93 | CA-2015-149587 | 1/31/2015  | 2/5/2015  | Second Class | KB-16315    | Karl Braun    | Consumer | United States | Minneapolis | Minnesota  |       55407 | Central | OFF-PA-10003177 | Office Supplies | Paper        | Xerox 1999                                       |
|     94 | CA-2015-149587 | 1/31/2015  | 2/5/2015  | Second Class | KB-16315    | Karl Braun    | Consumer | United States | Minneapolis | Minnesota  |       55407 | Central | FUR-FU-10003799 | Furniture       | Furnishings  | Seth Thomas 13 1/2" Wall Clock                   |
|     95 | CA-2015-149587 | 1/31/2015  | 2/5/2015  | Second Class | KB-16315    | Karl Braun    | Consumer | United States | Minneapolis | Minnesota  |       55407 | Central | OFF-BI-10002852 | Office Supplies | Binders      | Ibico Standard Transparent Covers                |
+--------+----------------+------------+-----------+--------------+-------------+---------------+----------+---------------+-------------+------------+-------------+---------+-----------------+-----------------+--------------+--------------------------------------------------+
5 rows in set (0.002 sec)

# %% [markdown]
# ## Step 4: Use GROUP BY for aggregations

# %%
# Using group by to see aggregated results
MariaDB [superstore_db]> select sub_category, count(order_id) as quantity_sold from superstore_data group by sub_category;
+--------------+---------------+
| sub_category | quantity_sold |
+--------------+---------------+
| Accessories  |           775 |
| Appliances   |           466 |
| Art          |           796 |
| Binders      |          1523 |
| Bookcases    |           228 |
| Chairs       |           617 |
| Copiers      |            68 |
| Envelopes    |           254 |
| Fasteners    |           217 |
| Furnishings  |           957 |
| Labels       |           364 |
| Machines     |           115 |
| Paper        |          1370 |
| Phones       |           889 |
| Storage      |           846 |
| Supplies     |           190 |
| Tables       |           319 |
+--------------+---------------+
17 rows in set (0.020 sec)

# %%
MariaDB [superstore_db]> select region, count(order_id) as sales from superstore_data group by region;
+---------+-------+
| region  | sales |
+---------+-------+
| Central |  2323 |
| East    |  2848 |
| South   |  1620 |
| West    |  3203 |
+---------+-------+

# %% [markdown]
# ## Step 5: Sort and limit results

# %%
# Sorting and limiting data using order by and limit clauses
MariaDB [superstore_db]> select product_name as top_products, count(order_id) as quantity_sold from superstore_data group by product_id order by quantity_sold desc limit 10;
+------------------------------------------------------------+---------------+
| top_products                                               | quantity_sold |
+------------------------------------------------------------+---------------+
| Xerox 1881                                                 |            19 |
| Logitech?P710e Mobile Speakerphone                         |            18 |
| Eldon Image Series Desk Accessories, Burgundy              |            16 |
| Logitech G19 Programmable Gaming Keyboard                  |            15 |
| Situations Contoured Folding Chairs, 4/Set                 |            15 |
| Logitech 910-002974 M325 Wireless Mouse for Web Scrolling  |            15 |
| Global Value Mid-Back Manager's Chair, Gray                |            15 |
| Xerox 1916                                                 |            14 |
| Global High-Back Leather Tilter, Burgundy                  |            14 |
| GBC Premium Transparent Covers with Diagonal Lined Pattern |            14 |
+------------------------------------------------------------+---------------+

# %%
MariaDB [superstore_db]> select category as top_categories, count(order_id) as quantity_sold from superstore_data group by category order by quantity_sold desc limit 10;
+-----------------+---------------+
| top_categories  | quantity_sold |
+-----------------+---------------+
| Office Supplies |          6026 |
| Furniture       |          2121 |
| Technology      |          1847 |
+-----------------+---------------+

# %%
MariaDB [superstore_db]> select category as top_categories, sub_category, count(order_id) as quantity_sold from superstore_data group by category, sub_category order by quantity_sold desc limit 10;
+-----------------+--------------+---------------+
| top_categories  | sub_category | quantity_sold |
+-----------------+--------------+---------------+
| Office Supplies | Binders      |          1523 |
| Office Supplies | Paper        |          1370 |
| Furniture       | Furnishings  |           957 |
| Technology      | Phones       |           889 |
| Office Supplies | Storage      |           846 |
| Office Supplies | Art          |           796 |
| Technology      | Accessories  |           775 |
| Furniture       | Chairs       |           617 |
| Office Supplies | Appliances   |           466 |
| Office Supplies | Labels       |           364 |
+-----------------+--------------+---------------+

# %% [markdown]
# ## Step 6: Solve use cases

# %%
# Analyzing data based on business use cases
MariaDB [superstore_db]> select customer_id as top_customers, count(order_id) as quantity_sold from superstore_data group by customer_id order by quantity_sold desc limit 20;
+---------------+---------------+
| top_customers | quantity_sold |
+---------------+---------------+
| WB-21850      |            37 |
| JL-15835      |            34 |
| MA-17560      |            34 |
| PP-18955      |            34 |
| SV-20365      |            32 |
| JD-15895      |            32 |
| EH-13765      |            32 |
| CK-12205      |            32 |
| EP-13915      |            31 |
| ZC-21910      |            31 |
| AP-10915      |            31 |
| LC-16870      |            30 |
| Dp-13240      |            29 |
| BM-11650      |            29 |
| GT-14710      |            29 |
| KL-16645      |            29 |
| SH-19975      |            29 |
| CS-12250      |            28 |
| KM-16720      |            28 |
| CL-12565      |            28 |
+---------------+---------------+

# %%
# Finding duplicate data
MariaDB [superstore_db]> select count(*) as total_rows, sum(case when order_id is null then 1 else 0 end) as null_values, sum(case when order_id = '' then 1 else 0 end) as blank_values from superstore_data;
+------------+-------------+--------------+
| total_rows | null_values | blank_values |
+------------+-------------+--------------+
|       9994 |           0 |            0 |
+------------+-------------+--------------+
1 row in set (0.225 sec)

# %% [markdown]
# ## Step 7: Validate results

# %%
# Total number of rows in table
MariaDB [superstore_db]> select count(*) as total_rows from superstore_data;
+------------+
| total_rows |
+------------+
|       9994 |
+------------+

# %%
# Total number of null and empty rows
MariaDB [superstore_db]> select count(*) as total_rows, sum(case when order_id is null then 1 else 0 end) as null_values, sum(case when order_id = '' then 1 else 0 end) as blank_values from superstore_data;
+------------+-------------+--------------+
| total_rows | null_values | blank_values |
+------------+-------------+--------------+
|       9994 |           0 |            0 |
+------------+-------------+--------------+
1 row in set (0.225 sec)
